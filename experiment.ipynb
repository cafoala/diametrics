# %%
import pandas as pd
import numpy as np
#from diametrics import transform
from src.diametrics import transform, metrics, preprocessing, visualisations
#import transformData

# %%
glc_data = transform.transform_data('tests/test_data/dexcom/', 'dexcom')
glc_data_procsd = preprocessing.replace_cutoffs(glc_data)

glc_data_procsd.groupby('ID').apply(metrics.all_metrics)
# Out:
#                       Start DateTime         End DateTime
# ID
# dexcom_eur_01 0  2023-03-08 00:04:00  2023-03-21 15:29:00  \
# dexcom_eur_02 0  2023-03-08 00:01:00  2023-03-21 15:31:00
# dexcom_eur_03 0  2023-03-08 00:01:00  2023-03-21 15:40:00
#
#                  Data Sufficiency (%)              Days  Average glucose
# ID
# dexcom_eur_01 0                  97.4  13 days 15:25:00         9.151752  \
# dexcom_eur_02 0                  98.0  13 days 15:30:00         7.866179
# dexcom_eur_03 0                  97.1  13 days 15:39:00         8.212228
#
#                        SD     CV (%)  eA1c (%)  Min. glucose  Max. glucose
# ID
# dexcom_eur_01 0  3.121628  34.109626  7.384750           2.4          22.1  \
# dexcom_eur_02 0  3.085039  39.219034  6.576213           2.2          22.1
# dexcom_eur_03 0  3.256385  39.652884  6.793854           2.2          19.9
#
#                  ...  Number LV2 hypoglycemic events
# ID               ...
# ...

# %%
preprocessing.check_df(glc_data_procsd)
# Out:
# True

# %%
dxcm1 = transform.transform_data('tests/test_data/dexcom/dexcom_eur_01.xlsx', 'dexcom')
dxcm2 = pd.read_excel('tests/test_data/dexcom/dexcom_eur_02.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dxcm1 = transform.transform_data('tests/test_data/dexcom/dexcom_eur_01.xlsx', 'dexcom')
#       2 dxcm2 = pd.read_excel('tests/test_data/dexcom/dexcom_eur_02.xlsx')
#
# File ~/Desktop/projects/diametrics/src/diametrics/transform.py:105, in transform_data(directory, device)
#     103 def transform_data(directory, device):
#     104     total_cgm = []
# --> 105     for filename in os.listdir(directory):
#     106         # Read the file using pandas
#     107         filepath =  directory  + '/' + filename
#     108         df = open_file(filepath)
#
# NotADirectoryError: [Errno 20] Not a directory: 'tests/test_data/dexcom/dexcom_eur_01.xlsx'

# %%
transformed = [transform.transformData(i, 'Dexcom') for i in [dxcm1, dxcm2]]
cutoffs = [preprocessing.replace_cutoffs(i) for i in transformed]
metric_results = [metrics.all_metrics(i, return_df=False) for i in transformed]

# %%
metric_results
# Out:
# [{'Start DateTime': '2023-03-08 00:04:00',
#   'End DateTime': '2023-03-21 15:29:00',
#   'Data Sufficiency (%)': 97.3,
#   'Days': '13 days 15:25:00',
#   'Average glucose': 9.15175209205021,
#   'SD': 3.121628424921161,
#   'CV (%)': 34.10962615161751,
#   'eA1c (%)': 7.384749743427804,
#   'Min. glucose': 2.4,
#   'Max. glucose': 22.1,
#   'AUC': 8.291684912008282,
#   'LBGI': 0.30107368594005984,
#   'HBGI': 7.413576868991013,
#   'MAGE': 7.971621621621622,
#   'TIR normal': 64.83,
#   'TIR level 1 hypoglycemia': 0.71,
#   'TIR level 2 hypoglycemia': 0.03,
#   'TIR level 1 hyperglycemia': 26.54,
#   'TIR level 2 hyperglycemia': 7.9,
#   'Total number hypoglycemic events': 4,
#   'Number LV1 hypoglycemic events': 4,
#   'Number LV2 hypoglycemic events': 0,
#   'Number prolonged hypoglycemic events': 0,
#   'Avg. length of hypoglycemic events': '0 days 00:31:16',
#   'Total time spent in hypoglycemic events': '0 days 02:05:02',
#   'Total number hyperglycemic events': 33,
# ...

# %%
cutoffs[0].interval
# Out:
# 5

# %%
pd.DataFrame.from_dict(metric_results)
# Out:
#         Start DateTime         End DateTime  Data Sufficiency (%)
# 0  2023-03-08 00:04:00  2023-03-21 15:29:00                  97.3  \
# 1  2023-03-08 00:01:00  2023-03-21 15:31:00                  97.4
#
#                Days  Average glucose        SD     CV (%)  eA1c (%)
# 0  13 days 15:25:00         9.151752  3.121628  34.109626  7.384750  \
# 1  13 days 15:30:00         7.866179  3.085039  39.219034  6.576213
#
#    Min. glucose  Max. glucose  ...  Number LV2 hypoglycemic events
# 0           2.4          22.1  ...                               0  \
# 1           2.2          22.1  ...                               9
#
#    Number prolonged hypoglycemic events  Avg. length of hypoglycemic events
# 0                                     0                     0 days 00:31:16  \
# 1                                     0                     0 days 01:00:58
#
#    Total time spent in hypoglycemic events  Total number hyperglycemic events
# ...

# %%
visualisations.create_bargraph(metric_results, 'Time in range')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 visualisations.create_bargraph(metric_results, 'Time in range')
#
# File ~/Desktop/projects/diametrics/src/diametrics/visualisations.py:173, in create_bargraph(df, y_axis)
#     171 else:
#     172     y_value=y_axis
# --> 173 fig = px.bar(df, x='ID', y=y_value)
#     174 return fig
#
# ...

# %% [markdown]
# ### TIR

# %%
df = transformed[0].data

# %%
metrics.glycemic_episodes(df)
# Out:
# {'Total number hypoglycemic events': 4,
#  'Number LV1 hypoglycemic events': 4,
#  'Number LV2 hypoglycemic events': 0,
#  'Number prolonged hypoglycemic events': 0,
#  'Avg. length of hypoglycemic events': '0 days 00:31:16',
#  'Total time spent in hypoglycemic events': '0 days 02:05:02',
#  'Total number hyperglycemic events': 33,
#  'Number LV1 hyperglycemic events': 20,
#  'Number LV2 hyperglycemic events': 13,
#  'Number prolonged hyperglycemic events': 5,
#  'Avg. length of hyperglycemic events': '0 days 03:30:37',
#  'Total time spent in hyperglycemic events': '4 days 19:50:13'}

# %%
metrics.calculate_glycemic_episodes_dicts(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/package_play/lib/python3.9/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/miniconda3/envs/package_play/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/package_play/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'start_time'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
dxcm1_transformed = transform.transformData(dxcm1, 'Dexcom')

# %%
dxcm1_transformed.data = preprocessing.replace_cutoffs(dxcm1_transformed.data)

# %%
visualisations.glucose_trace(dxcm1_transformed.data)

# %%
visualisations.tir_pie(dxcm1_transformed.data)

# %%
visualisations.agp(dxcm1_transformed.data)
